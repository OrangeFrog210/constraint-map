# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
f1 = "gencode.v40.pc_translations.headers.txt"

# %%
df = pd.read_csv(f1, header=None, sep="|", names=["protein-id", "transcript-id", "gene-id", "Havana-gene-id", "Havana-transcript-id", "transcript-name", "gene-name", "sequence-length"])
df
# Out:
#                 protein-id      transcript-id             gene-id  \
# 0       >ENSP00000493376.2  ENST00000641515.2   ENSG00000186092.7
# 1       >ENSP00000409316.1  ENST00000426406.4   ENSG00000284733.2
# 2       >ENSP00000329982.2  ENST00000332831.5   ENSG00000284662.2
# 3       >ENSP00000478421.2  ENST00000616016.5  ENSG00000187634.13
# 4       >ENSP00000480678.2  ENST00000618323.5  ENSG00000187634.13
# ...                    ...                ...                 ...
# 108568  >ENSP00000354728.1  ENST00000361335.1   ENSG00000212907.2
# 108569  >ENSP00000354961.2  ENST00000361381.2   ENSG00000198886.2
# 108570  >ENSP00000354813.2  ENST00000361567.2   ENSG00000198786.2
# 108571  >ENSP00000354665.2  ENST00000361681.2   ENSG00000198695.2
# 108572  >ENSP00000354554.2  ENST00000361789.2   ENSG00000198727.2
#
#                Havana-gene-id  Havana-transcript-id transcript-name gene-name  \
# 0        OTTHUMG00000001094.4  OTTHUMT00000003223.4       OR4F5-201     OR4F5
# ...

# %%
df_succinct = df[["protein-id", "transcript-id", "gene-id", "gene-name", "sequence-length"]]
df_succinct["PROTEIN-id"] = df_succinct["protein-id"].str.replace(">", "")
df_succinct
# Out:
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_30724\1997582863.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_succinct["PROTEIN-id"] = df_succinct["protein-id"].str.replace(">", "")
#                 protein-id      transcript-id             gene-id gene-name  \
# 0       >ENSP00000493376.2  ENST00000641515.2   ENSG00000186092.7     OR4F5
# 1       >ENSP00000409316.1  ENST00000426406.4   ENSG00000284733.2    OR4F29
# 2       >ENSP00000329982.2  ENST00000332831.5   ENSG00000284662.2    OR4F16
# 3       >ENSP00000478421.2  ENST00000616016.5  ENSG00000187634.13    SAMD11
# 4       >ENSP00000480678.2  ENST00000618323.5  ENSG00000187634.13    SAMD11
# ...                    ...                ...                 ...       ...
# ...

# %%
df_succinct[df_succinct["sequence-length"] < 99].sample(10)
# Out:
#                 protein-id      transcript-id             gene-id gene-name  \
# 52297   >ENSP00000507505.1  ENST00000684434.1  ENSG00000148672.10     GLUD1
# 101380  >ENSP00000389291.1  ENST00000437338.5  ENSG00000166979.13     EVA1C
# 14475   >ENSP00000510714.1  ENST00000685403.1  ENSG00000079150.19     FKBP7
# 6027    >ENSP00000426521.1  ENST00000509409.5  ENSG00000143549.21      TPM3
# 21110   >ENSP00000418931.1  ENST00000496145.5  ENSG00000065371.18     ROPN1
# 32602   >ENSP00000424654.1  ENST00000509148.1  ENSG00000204628.12     RACK1
# 67179   >ENSP00000498286.1  ENST00000652466.1   ENSG00000111328.7   CDK2AP1
# 76951   >ENSP00000454486.1  ENST00000570280.5  ENSG00000140983.14     RHOT2
# 83804   >ENSP00000486754.1  ENST00000628188.1  ENSG00000177731.16      FLII
# 40795   >ENSP00000418679.1  ENST00000478915.1  ENSG00000146776.15   ATXN7L1
#
#         sequence-length         PROTEIN-id
# 52297                39  ENSP00000507505.1
# 101380               70  ENSP00000389291.1
# ...

# %% [markdown]
# ### To Run

# %% [markdown]
# - bin1: 90-99
# - bin2: 190-199
# - bin3: 290-299
# - bin4: 490-499
# - bin5: 690-699
# - bin6: 890-899
# - bin7: 1090-1099
# - bin8: 1290-1399

# %%
#df_succinct[df_succinct["sequence-length"] >1200]
lower = 690
upper = 699
df_n1 = df_succinct[df_succinct["sequence-length"] <= upper]
df_proteinID = df_n1[df_n1["sequence-length"] >= lower ].sample(100)
df_proteinID
# Out:
#                 protein-id       transcript-id             gene-id gene-name  \
# 56851   >ENSP00000378449.2   ENST00000395001.5  ENSG00000166928.11    MS4A14
# 27320   >ENSP00000296518.7  ENST00000296518.11  ENSG00000164116.17   GUCY1A1
# 96233   >ENSP00000221462.3   ENST00000221462.9  ENSG00000104866.11   PPP1R37
# 106632  >ENSP00000493598.1   ENST00000646118.1  ENSG00000184788.14     SATL1
# 81260   >ENSP00000454218.1   ENST00000562090.5  ENSG00000090863.12      GLG1
# ...                    ...                 ...                 ...       ...
# 107040  >ENSP00000495685.1   ENST00000483338.1  ENSG00000188153.14    COL4A5
# 49538   >ENSP00000503696.1   ENST00000678303.1  ENSG00000130714.19     POMT1
# 103395  >ENSP00000371441.5   ENST00000382011.9  ENSG00000100297.16      MCM5
# 843     >ENSP00000502145.1   ENST00000675987.1  ENSG00000116688.18      MFN2
# 39342   >ENSP00000391129.1   ENST00000429192.5  ENSG00000049540.19       ELN
#
#         sequence-length         PROTEIN-id
# ...

# %%
fout = str(lower) + "_" + str(upper) + ".txt" 
df_proteinID["PROTEIN-id"].to_csv(fout, header=None, index=False)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Yumika\anaconda3-2\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Yumika\anaconda3-2\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\Yumika\anaconda3-2\lib\asyncio\events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\Yumika\anaconda3-2\lib\asyncio\selector_events.py", line 120, in _read_from_self
#     data = self._ssock.recv(4096)
# ...

# %%
df_succinct[df_succinct["sequence-length"] <= 1000]
# Out:
#                 protein-id      transcript-id             gene-id gene-name  \
# 0       >ENSP00000493376.2  ENST00000641515.2   ENSG00000186092.7     OR4F5
# 1       >ENSP00000409316.1  ENST00000426406.4   ENSG00000284733.2    OR4F29
# 2       >ENSP00000329982.2  ENST00000332831.5   ENSG00000284662.2    OR4F16
# 3       >ENSP00000478421.2  ENST00000616016.5  ENSG00000187634.13    SAMD11
# 4       >ENSP00000480678.2  ENST00000618323.5  ENSG00000187634.13    SAMD11
# ...                    ...                ...                 ...       ...
# 108568  >ENSP00000354728.1  ENST00000361335.1   ENSG00000212907.2   MT-ND4L
# 108569  >ENSP00000354961.2  ENST00000361381.2   ENSG00000198886.2    MT-ND4
# 108570  >ENSP00000354813.2  ENST00000361567.2   ENSG00000198786.2    MT-ND5
# 108571  >ENSP00000354665.2  ENST00000361681.2   ENSG00000198695.2    MT-ND6
# 108572  >ENSP00000354554.2  ENST00000361789.2   ENSG00000198727.2    MT-CYB
#
#         sequence-length
# 0                   326
# ...

# %%
df_succinct[df_succinct["sequence-length"] > 1000]
# Out:
#                 protein-id      transcript-id             gene-id gene-name  \
# 30      >ENSP00000368678.2  ENST00000379370.7  ENSG00000188157.15      AGRN
# 31      >ENSP00000484607.1  ENST00000620552.4  ENSG00000188157.15      AGRN
# 32      >ENSP00000499046.1  ENST00000651234.1  ENSG00000188157.15      AGRN
# 33      >ENSP00000498543.1  ENST00000652369.1  ENSG00000188157.15      AGRN
# 236     >ENSP00000417061.2  ENST00000493964.5  ENSG00000142609.20    CFAP74
# ...                    ...                ...                 ...       ...
# 108470  >ENSP00000330446.5  ENST00000329134.9  ENSG00000183878.16       UTY
# 108493  >ENSP00000322408.4  ENST00000317961.9  ENSG00000012817.16     KDM5D
# 108494  >ENSP00000444293.1  ENST00000541639.5  ENSG00000012817.16     KDM5D
# 108495  >ENSP00000372256.2  ENST00000382806.6  ENSG00000012817.16     KDM5D
# 108496  >ENSP00000398543.1  ENST00000440077.5  ENSG00000012817.16     KDM5D
#
#         sequence-length
# 30                 2045
# ...

# %%
df_threshold = pd.DataFrame(columns= ['Threshold', 'LessThanEqual', 'Above']) 
binsize = 50
list_bins = [i for i in range (0, 1050, binsize)]
print(list_bins)
for threshold in list_bins:
    lte = df_succinct[df_succinct["sequence-length"] <= threshold].shape[0]
    above = df_succinct[df_succinct["sequence-length"] > threshold].shape[0]
    df_threshold = df_threshold.append ({'Threshold' : threshold, 'LessThanEqual' : lte, 'Above' : above}, ignore_index = True)
df_threshold
# Out:
# [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]
#    Threshold LessThanEqual   Above
# 0          0             0  108573
# 1         50          6771  101802
# 2        100         21346   87227
# 3        150         35952   72621
# 4        200         47654   60919
# 5        250         55599   52974
# 6        300         61862   46711
# 7        350         67918   40655
# 8        400         72942   35631
# 9        450         77364   31209
# 10       500         81651   26922
# 11       550         85195   23378
# 12       600         88128   20445
# 13       650         90551   18022
# 14       700         92695   15878
# 15       750         94680   13893
# 16       800         96283   12290
# 17       850         97645   10928
# 18       900         98826    9747
# 19       950         99949    8624
# 20      1000        100798    7775

# %%
df_threshold["LTE-percentage"] = df_threshold["LessThanEqual"] / df.shape[0] * 100
df_threshold["Above-percentage"] = df_threshold["Above"] / df.shape[0] * 100
df_threshold
# Out:
#    Threshold LessThanEqual   Above LTE-percentage Above-percentage
# 0          0             0  108573            0.0            100.0
# 1         50          6771  101802       6.236357        93.763643
# 2        100         21346   87227      19.660505        80.339495
# 3        150         35952   72621      33.113205        66.886795
# 4        200         47654   60919      43.891207        56.108793
# 5        250         55599   52974      51.208864        48.791136
# 6        300         61862   46711      56.977333        43.022667
# 7        350         67918   40655      62.555147        37.444853
# 8        400         72942   35631      67.182449        32.817551
# 9        450         77364   31209      71.255284        28.744716
# 10       500         81651   26922       75.20378         24.79622
# 11       550         85195   23378      78.467943        21.532057
# 12       600         88128   20445      81.169351        18.830649
# ...

# %%
df_threshold = df_threshold.append ({'Threshold' : 500, 'LessThanEqual' : 15000, 'Above' : 1922}, ignore_index = True)

# %%
binsize = 50
list_bins = [i for i in range (0, 1050, binsize)]
print(list_bins)
for threshold in list_bins:
    print(threshold)
    print(" Less than equal to: "+ str(df_succinct[df_succinct["sequence-length"] <= threshold].shape[0]))
    print(" Above: "+ str(df_succinct[df_succinct["sequence-length"] > threshold].shape[0]))
    print("-----------")
# Out:
# [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]
# 0
#  Less than equal to: 0
#  Above: 108573
# -----------
# 50
#  Less than equal to: 6771
#  Above: 101802
# -----------
# 100
#  Less than equal to: 21346
#  Above: 87227
# -----------
# 150
#  Less than equal to: 35952
#  Above: 72621
# -----------
# 200
#  Less than equal to: 47654
#  Above: 60919
# -----------
# 250
#  Less than equal to: 55599
#  Above: 52974
# -----------
# 300
#  Less than equal to: 61862
#  Above: 46711
# -----------
# 350
#  Less than equal to: 67918
#  Above: 40655
# -----------
# 400
#  Less than equal to: 72942
#  Above: 35631
# -----------
# 450
#  Less than equal to: 77364
#  Above: 31209
# -----------
# 500
#  Less than equal to: 81651
#  Above: 26922
# -----------
# 550
#  Less than equal to: 85195
#  Above: 23378
# -----------
# 600
#  Less than equal to: 88128
#  Above: 20445
# -----------
# 650
#  Less than equal to: 90551
#  Above: 18022
# ...

# %%
binsize = 50
list_bins = [i for i in range (0, 1050, binsize)]
print(list_bins)
for threshold in list_bins:
    print(threshold)
    print(" Less than equal to " + str(threshold) + ":" + str(df_succinct[df_succinct["sequence-length"] <= threshold].shape[0]))
    print(" Above " +  str(threshold) + ":" + str(df_succinct[df_succinct["sequence-length"] > threshold].shape[0]))
    print("-----------")
# Out:
# [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000]
# 0
#  Less than equal to 0:0
#  Above 0:108573
# -----------
# 50
#  Less than equal to 50:6771
#  Above 50:101802
# -----------
# 100
#  Less than equal to 100:21346
#  Above 100:87227
# -----------
# 150
#  Less than equal to 150:35952
#  Above 150:72621
# -----------
# 200
#  Less than equal to 200:47654
#  Above 200:60919
# -----------
# 250
#  Less than equal to 250:55599
#  Above 250:52974
# -----------
# 300
#  Less than equal to 300:61862
#  Above 300:46711
# -----------
# 350
#  Less than equal to 350:67918
#  Above 350:40655
# -----------
# 400
#  Less than equal to 400:72942
#  Above 400:35631
# -----------
# 450
#  Less than equal to 450:77364
#  Above 450:31209
# -----------
# 500
#  Less than equal to 500:81651
#  Above 500:26922
# -----------
# 550
#  Less than equal to 550:85195
#  Above 550:23378
# -----------
# 600
#  Less than equal to 600:88128
# ...

# %%
df_succinct[df_succinct["sequence-length"] <= 1000]
df_succinct[df_succinct["sequence-length"] > 500]
# Out:
#                 protein-id             transcript-id  \
# 3       >ENSP00000478421.2         ENST00000616016.5
# 4       >ENSP00000480678.2         ENST00000618323.5
# 6       >ENSP00000342313.3         ENST00000342066.8
# 7       >ENSP00000484643.1         ENST00000616125.5
# 8       >ENSP00000484256.1         ENST00000618779.5
# ...                    ...                       ...
# 108551  >ENSP00000354799.2         ENST00000361963.3
# 108552  >ENSP00000302968.4         ENST00000306609.4
# 108557  >ENSP00000244174.5  ENST00000244174.11_PAR_Y
# 108562  >ENSP00000354499.2         ENST00000361624.2
# 108570  >ENSP00000354813.2         ENST00000361567.2
#
#                          gene-id gene-name  sequence-length
# 3             ENSG00000187634.13    SAMD11              844
# 4             ENSG00000187634.13    SAMD11              845
# 6             ENSG00000187634.13    SAMD11              681
# 7             ENSG00000187634.13    SAMD11              573
# ...

# %% [markdown]
# 12. gencode.vX.pc_translations.fa.gz:
# Translations of protein-coding transcripts on reference chromosomes Fasta file.
#   The sequence headers contain the following fields:
#     1. transcript-id|
#     2. gene-id|
#     3. Havana-gene-id (if the gene contains manually annotated transcripts, '-' otherwise)|
#     4. Havana-transcript-id (if this transcript was manually annotated, '-' otherwise)|
#     5. transcript-name|
#     6. gene-name|
#     7. sequence-length

# %%
df_protein_counts = df["protein-id"].value_counts(sort=True).rename_axis('unique_proteins').reset_index(name='counts')
df_protein_counts
# Out:
#            unique_proteins  counts
# 0       >ENSP00000414867.1       2
# 1       >ENSP00000370660.3       2
# 2       >ENSP00000370940.3       2
# 3       >ENSP00000485427.1       2
# 4       >ENSP00000370718.3       2
# ...                    ...     ...
# 108495  >ENSP00000366215.4       1
# 108496  >ENSP00000442786.1       1
# 108497  >ENSP00000467496.1       1
# 108498  >ENSP00000338523.4       1
# 108499  >ENSP00000404801.1       1
#
# [108500 rows x 2 columns]

# %%
list_count2proteins = df_protein_counts[df_protein_counts["counts"] != 1].unique_proteins.values.tolist()
print(list_count2proteins)
print(len(list_count2proteins))
# Out:
# ['>ENSP00000414867.1', '>ENSP00000370660.3', '>ENSP00000370940.3', '>ENSP00000485427.1', '>ENSP00000370718.3', '>ENSP00000392053.1', '>ENSP00000479999.1', '>ENSP00000370631.3', '>ENSP00000512483.1', '>ENSP00000394848.2', '>ENSP00000327890.4', '>ENSP00000446410.1', '>ENSP00000370616.3', '>ENSP00000419148.1', '>ENSP00000370990.1', '>ENSP00000371038.4', '>ENSP00000400904.1', '>ENSP00000370639.3', '>ENSP00000244174.5', '>ENSP00000370979.4', '>ENSP00000335505.3', '>ENSP00000370987.1', '>ENSP00000316598.5', '>ENSP00000370588.3', '>ENSP00000370579.1', '>ENSP00000370570.3', '>ENSP00000370920.3', '>ENSP00000416437.2', '>ENSP00000420788.2', '>ENSP00000348058.2', '>ENSP00000370911.1', '>ENSP00000512496.1', '>ENSP00000399510.1', '>ENSP00000370697.4', '>ENSP00000370878.2', '>ENSP00000435479.1', '>ENSP00000430039.1', '>ENSP00000347606.3', '>ENSP00000370627.4', '>ENSP00000370620.2', '>ENSP00000383641.3', '>ENSP00000402741.1', '>ENSP00000498725.1', '>ENSP00000286448.6', '>ENSP00000370621.4', '>ENSP0
# ...

# %%
print(df['protein-id'].isin(list_count2proteins))
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 108568    False
# 108569    False
# 108570    False
# 108571    False
# 108572    False
# Name: protein-id, Length: 108573, dtype: bool

# %%
df_count2proteins = df[pd.DataFrame(df["protein-id"].tolist()).isin(list_count2proteins).any(1).values].sort_values(by="protein-id")
df_count2proteins
# Out:
#                 protein-id             transcript-id  \
# 108557  >ENSP00000244174.5  ENST00000244174.11_PAR_Y
# 108339  >ENSP00000244174.5        ENST00000244174.11
# 108337  >ENSP00000262640.6        ENST00000262640.11
# 108555  >ENSP00000262640.6  ENST00000262640.11_PAR_Y
# 108553  >ENSP00000286448.6  ENST00000286448.12_PAR_Y
# ...                    ...                       ...
# 104540  >ENSP00000508521.1         ENST00000686671.1
# 108362  >ENSP00000512483.1   ENST00000498153.7_PAR_Y
# 104546  >ENSP00000512483.1         ENST00000498153.7
# 104548  >ENSP00000512496.1         ENST00000696230.1
# 108364  >ENSP00000512496.1   ENST00000696230.1_PAR_Y
#
#                          gene-id        Havana-gene-id  Havana-transcript-id  \
# 108557  ENSG00000124334.18_PAR_Y  OTTHUMG00000022720.1  OTTHUMT00000058981.1
# 108339        ENSG00000124334.18  OTTHUMG00000022720.1  OTTHUMT00000058981.1
# 108337        ENSG00000124333.16  OTTHUMG00000022679.3  OTTHUMT00000058842.1
# ...

# %%
list_seqlen_count2proteins = df_count2proteins["sequence-length"].values.tolist()
print(list_seqlen_count2proteins)
# Out:
# [521, 521, 260, 260, 220, 220, 516, 516, 695, 695, 378, 378, 330, 330, 225, 225, 377, 377, 233, 233, 342, 342, 22, 22, 76, 76, 177, 177, 169, 169, 185, 185, 694, 694, 694, 694, 694, 694, 345, 345, 298, 298, 373, 373, 446, 446, 359, 359, 621, 621, 605, 605, 298, 298, 300, 300, 333, 333, 410, 410, 400, 400, 400, 400, 371, 371, 259, 259, 225, 225, 292, 292, 169, 169, 323, 323, 575, 575, 323, 323, 371, 371, 232, 232, 124, 124, 174, 174, 178, 178, 60, 60, 121, 121, 174, 174, 74, 74, 238, 238, 88, 88, 124, 124, 164, 164, 400, 400, 271, 271, 24, 24, 179, 179, 59, 59, 385, 385, 285, 285, 563, 563, 90, 90, 160, 160, 232, 232, 184, 184, 160, 160, 40, 40, 160, 160, 694, 694, 478, 478, 292, 292, 434, 434, 59, 59]

# %%
df_count2proteins[df_count2proteins["sequence-length"] == 694] 
# They are different proteins. They happen to have the same sequence length.
# Out:
#                 protein-id            transcript-id                   gene-id  \
# 108397  >ENSP00000370616.3  ENST00000381218.8_PAR_Y  ENSG00000214717.12_PAR_Y
# 104581  >ENSP00000370616.3        ENST00000381218.8        ENSG00000214717.12
# 108394  >ENSP00000370620.2  ENST00000381222.8_PAR_Y  ENSG00000214717.12_PAR_Y
# 104578  >ENSP00000370620.2        ENST00000381222.8        ENSG00000214717.12
# 108395  >ENSP00000370621.4  ENST00000381223.9_PAR_Y  ENSG00000214717.12_PAR_Y
# 104579  >ENSP00000370621.4        ENST00000381223.9        ENSG00000214717.12
# 104580  >ENSP00000498725.1        ENST00000652001.1        ENSG00000214717.12
# 108396  >ENSP00000498725.1  ENST00000652001.1_PAR_Y  ENSG00000214717.12_PAR_Y
#
#                Havana-gene-id  Havana-transcript-id transcript-name gene-name  \
# 108397  OTTHUMG00000021069.10  OTTHUMT00000144310.3       ZBED1-201     ZBED1
# 104581  OTTHUMG00000021069.10  OTTHUMT00000144310.3       ZBED1-201     ZBED1
# ...

# %%
df[df["protein-id"].str.contains("ENSP00000485545.1")]
# Out:
#                 protein-id            transcript-id                   gene-id  \
# 104590  >ENSP00000485545.1        ENST00000623253.4        ENSG00000002586.20
# 108406  >ENSP00000485545.1  ENST00000623253.4_PAR_Y  ENSG00000002586.20_PAR_Y
#
#                Havana-gene-id  Havana-transcript-id transcript-name gene-name  \
# 104590  OTTHUMG00000021073.12  OTTHUMT00000478891.1        CD99-211      CD99
# 108406  OTTHUMG00000021073.12  OTTHUMT00000478891.1        CD99-211      CD99
#
#         sequence-length
# 104590              160
# 108406              160

# %%
df["sequence-length"].describe()
# Out:
# count    108573.000000
# mean        389.834637
# std         511.718740
# min           1.000000
# 25%         120.000000
# 50%         242.000000
# 75%         497.000000
# max       35991.000000
# Name: sequence-length, dtype: float64

# %%
binsize = 20
list_bins = [i for i in range (0, 30000, binsize)]
# print(list_bins)
plt.hist(df["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
binsize = 20
list_bins = [i for i in range (0, 5000, binsize)]
plt.hist(df["sequence-length"], bins=list_bins)
# Out:
# (array([9.460e+02, 2.754e+03, 5.648e+03, 5.940e+03, 5.809e+03, 6.018e+03,
#         5.785e+03, 5.434e+03, 4.764e+03, 4.357e+03, 3.476e+03, 3.014e+03,
#         2.879e+03, 2.492e+03, 2.412e+03, 2.610e+03, 2.376e+03, 2.173e+03,
#         2.085e+03, 1.865e+03, 1.815e+03, 1.795e+03, 1.720e+03, 1.822e+03,
#         1.597e+03, 1.469e+03, 1.438e+03, 1.274e+03, 1.180e+03, 1.132e+03,
#         1.013e+03, 9.960e+02, 8.230e+02, 9.360e+02, 8.140e+02, 8.230e+02,
#         7.730e+02, 7.480e+02, 6.150e+02, 6.400e+02, 5.400e+02, 5.770e+02,
#         5.040e+02, 4.730e+02, 4.490e+02, 5.120e+02, 4.380e+02, 3.760e+02,
#         3.660e+02, 2.950e+02, 3.060e+02, 2.890e+02, 2.990e+02, 3.030e+02,
#         2.600e+02, 2.440e+02, 2.760e+02, 2.440e+02, 2.530e+02, 2.440e+02,
#         2.260e+02, 2.420e+02, 1.920e+02, 1.740e+02, 1.520e+02, 1.440e+02,
#         1.460e+02, 1.290e+02, 1.270e+02, 1.140e+02, 9.800e+01, 1.100e+02,
#         1.080e+02, 1.170e+02, 1.000e+02, 9.300e+01, 7.900e+01, 7.500e+01,
# ...

# %%
binsize = 20
list_bins = [i for i in range (0, 5000, binsize)]
plt.hist(df["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
binsize = 20
list_bins = [i for i in range (0, 3000, binsize)]
plt.hist(df["sequence-length"], bins=list_bins)
# Out:
# (array([9.460e+02, 2.754e+03, 5.648e+03, 5.940e+03, 5.809e+03, 6.018e+03,
#         5.785e+03, 5.434e+03, 4.764e+03, 4.357e+03, 3.476e+03, 3.014e+03,
#         2.879e+03, 2.492e+03, 2.412e+03, 2.610e+03, 2.376e+03, 2.173e+03,
#         2.085e+03, 1.865e+03, 1.815e+03, 1.795e+03, 1.720e+03, 1.822e+03,
#         1.597e+03, 1.469e+03, 1.438e+03, 1.274e+03, 1.180e+03, 1.132e+03,
#         1.013e+03, 9.960e+02, 8.230e+02, 9.360e+02, 8.140e+02, 8.230e+02,
#         7.730e+02, 7.480e+02, 6.150e+02, 6.400e+02, 5.400e+02, 5.770e+02,
#         5.040e+02, 4.730e+02, 4.490e+02, 5.120e+02, 4.380e+02, 3.760e+02,
#         3.660e+02, 2.950e+02, 3.060e+02, 2.890e+02, 2.990e+02, 3.030e+02,
#         2.600e+02, 2.440e+02, 2.760e+02, 2.440e+02, 2.530e+02, 2.440e+02,
#         2.260e+02, 2.420e+02, 1.920e+02, 1.740e+02, 1.520e+02, 1.440e+02,
#         1.460e+02, 1.290e+02, 1.270e+02, 1.140e+02, 9.800e+01, 1.100e+02,
#         1.080e+02, 1.170e+02, 1.000e+02, 9.300e+01, 7.900e+01, 7.500e+01,
# ...

# %%
binsize = 20
list_bins = [i for i in range (0, 3000, binsize)]
plt.hist(df["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
binsize = 20
my_list = [i for i in range (0, 3500, binsize)]
print(my_list)
plt.hist(df['sequence-length'], bins=my_list)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Count")
# Out:
# [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180, 1200, 1220, 1240, 1260, 1280, 1300, 1320, 1340, 1360, 1380, 1400, 1420, 1440, 1460, 1480, 1500, 1520, 1540, 1560, 1580, 1600, 1620, 1640, 1660, 1680, 1700, 1720, 1740, 1760, 1780, 1800, 1820, 1840, 1860, 1880, 1900, 1920, 1940, 1960, 1980, 2000, 2020, 2040, 2060, 2080, 2100, 2120, 2140, 2160, 2180, 2200, 2220, 2240, 2260, 2280, 2300, 2320, 2340, 2360, 2380, 2400, 2420, 2440, 2460, 2480, 2500, 2520, 2540, 2560, 2580, 2600, 2620, 2640, 2660, 2680, 2700, 2720, 2740, 2760, 2780, 2800, 2820, 2840, 2860, 2880, 2900, 2920, 2940, 2960, 2980, 3000, 3020, 3040, 3060, 3080, 3100, 3120, 3140, 3160, 3180, 3200, 3220, 3240, 3260, 3280, 3300, 3320, 3340, 3360, 3380, 3400, 3420, 3440, 3460, 3480]
# ...

# %% [markdown]
# ## With 73 duplicates removed

# %%
df
# Out:
#                 protein-id      transcript-id             gene-id  \
# 0       >ENSP00000493376.2  ENST00000641515.2   ENSG00000186092.7
# 1       >ENSP00000409316.1  ENST00000426406.4   ENSG00000284733.2
# 2       >ENSP00000329982.2  ENST00000332831.5   ENSG00000284662.2
# 3       >ENSP00000478421.2  ENST00000616016.5  ENSG00000187634.13
# 4       >ENSP00000480678.2  ENST00000618323.5  ENSG00000187634.13
# ...                    ...                ...                 ...
# 108568  >ENSP00000354728.1  ENST00000361335.1   ENSG00000212907.2
# 108569  >ENSP00000354961.2  ENST00000361381.2   ENSG00000198886.2
# 108570  >ENSP00000354813.2  ENST00000361567.2   ENSG00000198786.2
# 108571  >ENSP00000354665.2  ENST00000361681.2   ENSG00000198695.2
# 108572  >ENSP00000354554.2  ENST00000361789.2   ENSG00000198727.2
#
#                Havana-gene-id  Havana-transcript-id transcript-name gene-name  \
# 0        OTTHUMG00000001094.4  OTTHUMT00000003223.4       OR4F5-201     OR4F5
# ...

# %%
df_dupdropped = df.drop_duplicates(subset=["protein-id"])
df_dupdropped
# Out:
#                 protein-id      transcript-id             gene-id  \
# 0       >ENSP00000493376.2  ENST00000641515.2   ENSG00000186092.7
# 1       >ENSP00000409316.1  ENST00000426406.4   ENSG00000284733.2
# 2       >ENSP00000329982.2  ENST00000332831.5   ENSG00000284662.2
# 3       >ENSP00000478421.2  ENST00000616016.5  ENSG00000187634.13
# 4       >ENSP00000480678.2  ENST00000618323.5  ENSG00000187634.13
# ...                    ...                ...                 ...
# 108568  >ENSP00000354728.1  ENST00000361335.1   ENSG00000212907.2
# 108569  >ENSP00000354961.2  ENST00000361381.2   ENSG00000198886.2
# 108570  >ENSP00000354813.2  ENST00000361567.2   ENSG00000198786.2
# 108571  >ENSP00000354665.2  ENST00000361681.2   ENSG00000198695.2
# 108572  >ENSP00000354554.2  ENST00000361789.2   ENSG00000198727.2
#
#                Havana-gene-id  Havana-transcript-id transcript-name gene-name  \
# 0        OTTHUMG00000001094.4  OTTHUMT00000003223.4       OR4F5-201     OR4F5
# ...

# %%
df_dupdropped["protein-id"].nunique()
# Out:
# 108500

# %%
df_dupdropped.describe()
# Out:
#        sequence-length
# count    108500.000000
# mean        389.895963
# std         511.864644
# min           1.000000
# 25%         120.000000
# 50%         242.000000
# 75%         498.000000
# max       35991.000000

# %% [markdown]
# ### bin size = 20

# %%
binsize = 20

# %%
list_bins = [i for i in range (0, 30000, binsize)]
# print(list_bins)
plt.hist(df_dupdropped["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df_dupdropped['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
list_bins = [i for i in range (0, 5000, binsize)]
# print(list_bins)
plt.hist(df_dupdropped["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df_dupdropped['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
list_bins = [i for i in range (0, 3000, binsize)]
# print(list_bins)
plt.hist(df_dupdropped["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df_dupdropped['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ### bin size = 50

# %%
binsize = 50

# %%
list_bins = [i for i in range (0, 30000, binsize)]
# print(list_bins)
plt.hist(df_dupdropped["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df_dupdropped['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
list_bins = [i for i in range (0, 5000, binsize)]
# print(list_bins)
plt.hist(df_dupdropped["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df_dupdropped['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
list_bins = [i for i in range (0, 3000, binsize)]
# print(list_bins)
plt.hist(df_dupdropped["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df_dupdropped['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
list_bins = [i for i in range (0, 1000, binsize)]
# print(list_bins)
plt.hist(df_dupdropped["sequence-length"], bins=list_bins)
plt.suptitle("Sequence Lengths Distribution: n = " + str(df_dupdropped['sequence-length'].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence Length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
