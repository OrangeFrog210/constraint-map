# %%
# Purpose: To analyze result of pydca

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
f_base_gplmdca = "gplmDCA_protein_MSAsize_seqlen_bin_all.txt"
f_base_pydca = "pydca_protein_MSAsize_seqlen_bin_all.txt"
f_pydca = "output_pydca_all.txt"
f_gplmdca = "output_gplmDCA_all.txt"

# %%
df_base_gplmdca = pd.read_csv(f_base_gplmdca, names=["Filename", "MSA_size", "Sequence_length", "Bin"])
df_base_pydca = pd.read_csv(f_base_pydca, names=["Filename", "MSA_size", "Sequence_length", "Bin"])
df_gplmdca = pd.read_csv(f_gplmdca, names=["Filename", "Execution_time", "Bin"])
df_pydca = pd.read_csv(f_pydca, names=["Filename", "Execution_time", "Bin"])

# %% [markdown]
# ### pydca

# %%
df_base_pydca
# Out:
#                                            Filename  MSA_size  \
# 0    Trimmed_ENSP00000202556.msa.a3m.reformatted.fa      3056
# 1    Trimmed_ENSP00000205214.msa.a3m.reformatted.fa      6642
# 2    Trimmed_ENSP00000255194.msa.a3m.reformatted.fa      2920
# 3    Trimmed_ENSP00000261778.msa.a3m.reformatted.fa      1099
# 4    Trimmed_ENSP00000261892.msa.a3m.reformatted.fa      3194
# ..                                              ...       ...
# 795  Trimmed_ENSP00000505395.msa.a3m.reformatted.fa      1013
# 796  Trimmed_ENSP00000512455.msa.a3m.reformatted.fa       534
# 797  Trimmed_ENSP00000512643.msa.a3m.reformatted.fa       488
# 798  Trimmed_ENSP00000512834.msa.a3m.reformatted.fa      1033
# 799  Trimmed_ENSP00000512907.msa.a3m.reformatted.fa       102
#
#      Sequence_length        Bin
# 0                 89  1090_1099
# 1                  0  1090_1099
# 2                400  1090_1099
# 3                651  1090_1099
# 4                  0  1090_1099
# ..               ...        ...
# 795               52      90_99
# 796               31      90_99
# 797               56      90_99
# 798               70      90_99
# 799               66      90_99
#
# [800 rows x 4 columns]

# %%
df_base_pydca["Filename"] = df_base_pydca["Filename"].str.split('_').str[1].str.split('.').str[0]
df_base_pydca
# Out:
#             Filename  MSA_size  Sequence_length        Bin
# 0    ENSP00000202556      3056               89  1090_1099
# 1    ENSP00000205214      6642                0  1090_1099
# 2    ENSP00000255194      2920              400  1090_1099
# 3    ENSP00000261778      1099              651  1090_1099
# 4    ENSP00000261892      3194                0  1090_1099
# ..               ...       ...              ...        ...
# 795  ENSP00000505395      1013               52      90_99
# 796  ENSP00000512455       534               31      90_99
# 797  ENSP00000512643       488               56      90_99
# 798  ENSP00000512834      1033               70      90_99
# 799  ENSP00000512907       102               66      90_99
#
# [800 rows x 4 columns]

# %% [markdown]
# ## pydca

# %%
df_pydca
# Out:
#                                            Filename  \
# 0                                               NaN
# 1    Trimmed_ENSP00000202556.msa.a3m.reformatted.fa
# 2    Trimmed_ENSP00000205214.msa.a3m.reformatted.fa
# 3    Trimmed_ENSP00000255194.msa.a3m.reformatted.fa
# 4    Trimmed_ENSP00000261778.msa.a3m.reformatted.fa
# ..                                              ...
# 803  Trimmed_ENSP00000505395.msa.a3m.reformatted.fa
# 804  Trimmed_ENSP00000512455.msa.a3m.reformatted.fa
# 805  Trimmed_ENSP00000512643.msa.a3m.reformatted.fa
# 806  Trimmed_ENSP00000512834.msa.a3m.reformatted.fa
# 807  Trimmed_ENSP00000512907.msa.a3m.reformatted.fa
#
#                                         Execution_time        Bin
# 0                    0 h 0 min 2 s elapsed for process  1090_1099
# 1    0 h 0 min 25 s elapsed for process Trimmed_ENS...  1090_1099
# 2    0 h 0 min 2 s elapsed for process Trimmed_ENSP...  1090_1099
# 3    0 h 40 min 21 s elapsed for process Trimmed_EN...  1090_1099
# 4    1 h 53 min 55 s elapsed for process Trimmed_EN...  1090_1099
# ..                                                 ...        ...
# 803  0 h 0 min 15 s elapsed for process Trimmed_ENS...      90_99
# 804  0 h 0 min 4 s elapsed for process Trimmed_ENSP...      90_99
# 805  0 h 0 min 10 s elapsed for process Trimmed_ENS...      90_99
# 806  0 h 0 min 26 s elapsed for process Trimmed_ENS...      90_99
# 807  0 h 0 min 5 s elapsed for process Trimmed_ENSP...      90_99
#
# [808 rows x 3 columns]

# %%
df_pydca["Filename"] = df_pydca["Filename"].str.split('_').str[1].str.split('.').str[0]
df_pydca
# Out:
#             Filename                                     Execution_time  \
# 0                NaN                  0 h 0 min 2 s elapsed for process
# 1    ENSP00000202556  0 h 0 min 25 s elapsed for process Trimmed_ENS...
# 2    ENSP00000205214  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# 3    ENSP00000255194  0 h 40 min 21 s elapsed for process Trimmed_EN...
# 4    ENSP00000261778  1 h 53 min 55 s elapsed for process Trimmed_EN...
# ..               ...                                                ...
# 803  ENSP00000505395  0 h 0 min 15 s elapsed for process Trimmed_ENS...
# 804  ENSP00000512455  0 h 0 min 4 s elapsed for process Trimmed_ENSP...
# 805  ENSP00000512643  0 h 0 min 10 s elapsed for process Trimmed_ENS...
# 806  ENSP00000512834  0 h 0 min 26 s elapsed for process Trimmed_ENS...
# 807  ENSP00000512907  0 h 0 min 5 s elapsed for process Trimmed_ENSP...
#
#            Bin
# 0    1090_1099
# 1    1090_1099
# 2    1090_1099
# 3    1090_1099
# 4    1090_1099
# ..         ...
# 803      90_99
# 804      90_99
# 805      90_99
# 806      90_99
# 807      90_99
#
# [808 rows x 3 columns]

# %%
print(df_pydca["Filename"].isna().sum())
df_pydca = df_pydca.dropna()
df_pydca
# Out:
# 8
#             Filename                                     Execution_time  \
# 1    ENSP00000202556  0 h 0 min 25 s elapsed for process Trimmed_ENS...
# 2    ENSP00000205214  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# 3    ENSP00000255194  0 h 40 min 21 s elapsed for process Trimmed_EN...
# 4    ENSP00000261778  1 h 53 min 55 s elapsed for process Trimmed_EN...
# 5    ENSP00000261892  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# ..               ...                                                ...
# 803  ENSP00000505395  0 h 0 min 15 s elapsed for process Trimmed_ENS...
# 804  ENSP00000512455  0 h 0 min 4 s elapsed for process Trimmed_ENSP...
# 805  ENSP00000512643  0 h 0 min 10 s elapsed for process Trimmed_ENS...
# 806  ENSP00000512834  0 h 0 min 26 s elapsed for process Trimmed_ENS...
# 807  ENSP00000512907  0 h 0 min 5 s elapsed for process Trimmed_ENSP...
#
#            Bin
# 1    1090_1099
# 2    1090_1099
# 3    1090_1099
# 4    1090_1099
# 5    1090_1099
# ..         ...
# 803      90_99
# 804      90_99
# 805      90_99
# 806      90_99
# 807      90_99
#
# [800 rows x 3 columns]

# %%
df_pydca["h"] = df_pydca["Execution_time"].str.split('h').str[0]
df_pydca["m"] = df_pydca["Execution_time"].str.split('h').str[1].str.split('min').str[0]
df_pydca["s"] = df_pydca["Execution_time"].str.split('h').str[1].str.split('min').str[1].str.split('s').str[0]
df_pydca
# Out:
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\578114840.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pydca["h"] = df_pydca["Execution_time"].str.split('h').str[0]
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\578114840.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pydca["m"] = df_pydca["Execution_time"].str.split('h').str[1].str.split('min').str[0]
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\578114840.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pydca["s"] = df_pydca["Execution_time"].str.split('h').str[1].str.split('min').str[1].str.split('s').str[0]
#             Filename                                     Execution_time  \
# 1    ENSP00000202556  0 h 0 min 25 s elapsed for process Trimmed_ENS...
# 2    ENSP00000205214  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# 3    ENSP00000255194  0 h 40 min 21 s elapsed for process Trimmed_EN...
# 4    ENSP00000261778  1 h 53 min 55 s elapsed for process Trimmed_EN...
# 5    ENSP00000261892  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# ..               ...                                                ...
# 803  ENSP00000505395  0 h 0 min 15 s elapsed for process Trimmed_ENS...
# 804  ENSP00000512455  0 h 0 min 4 s elapsed for process Trimmed_ENSP...
# 805  ENSP00000512643  0 h 0 min 10 s elapsed for process Trimmed_ENS...
# 806  ENSP00000512834  0 h 0 min 26 s elapsed for process Trimmed_ENS...
# 807  ENSP00000512907  0 h 0 min 5 s elapsed for process Trimmed_ENSP...
#
#            Bin   h     m     s
# 1    1090_1099  0     0    25
# 2    1090_1099  0     0     2
# 3    1090_1099  0    40    21
# 4    1090_1099  1    53    55
# 5    1090_1099  0     0     2
# ..         ...  ..   ...   ...
# 803      90_99  0     0    15
# 804      90_99  0     0     4
# 805      90_99  0     0    10
# 806      90_99  0     0    26
# 807      90_99  0     0     5
#
# [800 rows x 6 columns]

# %%
df_pydca["h"] = df_pydca["h"].astype(int)
df_pydca["m"] = df_pydca["m"].astype(int)
df_pydca["s"] = df_pydca["s"].astype(int)
#print(df_pydca.dtypes)
#print(df_pydca)
# Out:
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\726435457.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pydca["h"] = df_pydca["h"].astype(int)
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\726435457.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pydca["m"] = df_pydca["m"].astype(int)
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\726435457.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pydca["s"] = df_pydca["s"].astype(int)

# %%
df_pydca["Total_s"] = df_pydca["h"] * 3600 + df_pydca["m"] * 60 + df_pydca["s"]
df_pydca
# Out:
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\1159478689.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_pydca["Total_s"] = df_pydca["h"] * 3600 + df_pydca["m"] * 60 + df_pydca["s"]
#             Filename                                     Execution_time  \
# 1    ENSP00000202556  0 h 0 min 25 s elapsed for process Trimmed_ENS...
# 2    ENSP00000205214  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# 3    ENSP00000255194  0 h 40 min 21 s elapsed for process Trimmed_EN...
# 4    ENSP00000261778  1 h 53 min 55 s elapsed for process Trimmed_EN...
# 5    ENSP00000261892  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# ..               ...                                                ...
# 803  ENSP00000505395  0 h 0 min 15 s elapsed for process Trimmed_ENS...
# 804  ENSP00000512455  0 h 0 min 4 s elapsed for process Trimmed_ENSP...
# 805  ENSP00000512643  0 h 0 min 10 s elapsed for process Trimmed_ENS...
# 806  ENSP00000512834  0 h 0 min 26 s elapsed for process Trimmed_ENS...
# 807  ENSP00000512907  0 h 0 min 5 s elapsed for process Trimmed_ENSP...
#
#            Bin  h   m   s  Total_s
# 1    1090_1099  0   0  25       25
# 2    1090_1099  0   0   2        2
# 3    1090_1099  0  40  21     2421
# 4    1090_1099  1  53  55     6835
# 5    1090_1099  0   0   2        2
# ..         ... ..  ..  ..      ...
# 803      90_99  0   0  15       15
# 804      90_99  0   0   4        4
# 805      90_99  0   0  10       10
# 806      90_99  0   0  26       26
# 807      90_99  0   0   5        5
#
# [800 rows x 7 columns]

# %% [markdown]
# ## gplmDCA

# %%
df_base_gplmdca
# Out:
#                                   Filename  MSA_size  Sequence_length  \
# 0    ENSP00000255194.filtered.countVal.a3m       334             1094
# 1    ENSP00000261778.filtered.countVal.a3m       766             1094
# 2    ENSP00000263409.filtered.countVal.a3m       311             1097
# 3    ENSP00000264160.filtered.countVal.a3m       137             1099
# 4    ENSP00000264868.filtered.countVal.a3m       195             1097
# ..                                     ...       ...              ...
# 608  ENSP00000504562.filtered.countVal.a3m       989               90
# 609  ENSP00000505395.filtered.countVal.a3m       320               99
# 610  ENSP00000512455.filtered.countVal.a3m       139               95
# 611  ENSP00000512643.filtered.countVal.a3m       134               92
# 612  ENSP00000512834.filtered.countVal.a3m       818               96
#
#            Bin
# 0    1090_1099
# 1    1090_1099
# 2    1090_1099
# 3    1090_1099
# 4    1090_1099
# ..         ...
# 608      90_99
# 609      90_99
# 610      90_99
# 611      90_99
# 612      90_99
#
# [613 rows x 4 columns]

# %%
df_base_gplmdca["Filename"] = df_base_gplmdca["Filename"].str.split('.').str[0]
df_base_gplmdca
# Out:
#             Filename  MSA_size  Sequence_length        Bin
# 0    ENSP00000255194       334             1094  1090_1099
# 1    ENSP00000261778       766             1094  1090_1099
# 2    ENSP00000263409       311             1097  1090_1099
# 3    ENSP00000264160       137             1099  1090_1099
# 4    ENSP00000264868       195             1097  1090_1099
# ..               ...       ...              ...        ...
# 608  ENSP00000504562       989               90      90_99
# 609  ENSP00000505395       320               99      90_99
# 610  ENSP00000512455       139               95      90_99
# 611  ENSP00000512643       134               92      90_99
# 612  ENSP00000512834       818               96      90_99
#
# [613 rows x 4 columns]

# %%
df_gplmdca
# Out:
#                                   Filename  \
# 0                                      NaN
# 1    ENSP00000255194.filtered.countVal.a3m
# 2    ENSP00000261778.filtered.countVal.a3m
# 3    ENSP00000263409.filtered.countVal.a3m
# 4    ENSP00000264160.filtered.countVal.a3m
# ..                                     ...
# 616  ENSP00000504562.filtered.countVal.a3m
# 617  ENSP00000505395.filtered.countVal.a3m
# 618  ENSP00000512455.filtered.countVal.a3m
# 619  ENSP00000512643.filtered.countVal.a3m
# 620  ENSP00000512834.filtered.countVal.a3m
#
#                                         Execution_time        Bin
# 0    0 min 14 s elapsed for process 0 h 0 min 14 s ...  1090_1099
# 1    58 min 52 s elapsed for process 10 h 58 min 52...  1090_1099
# 2    1 min 18 s elapsed for process 17 h 1 min 18 s...  1090_1099
# 3    29 min 49 s elapsed for process 14 h 29 min 49...  1090_1099
# 4    18 min 10 s elapsed for process 9 h 18 min 10 ...  1090_1099
# ..                                                 ...        ...
# 616  3 min 31 s elapsed for process 0 h 3 min 31 s ...      90_99
# 617  2 min 5 s elapsed for process 0 h 2 min 5 s el...      90_99
# 618  1 min 19 s elapsed for process 0 h 1 min 19 s ...      90_99
# 619  Minimizing g_r for node r=92 Minimizing g_r fo...      90_99
# 620  1 min 53 s elapsed for process 0 h 1 min 53 s ...      90_99
#
# [621 rows x 3 columns]

# %%
df_gplmdca["Filename"] = df_gplmdca["Filename"].str.split('.').str[0]
df_gplmdca
# Out:
#             Filename                                     Execution_time  \
# 0                NaN  0 min 14 s elapsed for process 0 h 0 min 14 s ...
# 1    ENSP00000255194  58 min 52 s elapsed for process 10 h 58 min 52...
# 2    ENSP00000261778  1 min 18 s elapsed for process 17 h 1 min 18 s...
# 3    ENSP00000263409  29 min 49 s elapsed for process 14 h 29 min 49...
# 4    ENSP00000264160  18 min 10 s elapsed for process 9 h 18 min 10 ...
# ..               ...                                                ...
# 616  ENSP00000504562  3 min 31 s elapsed for process 0 h 3 min 31 s ...
# 617  ENSP00000505395  2 min 5 s elapsed for process 0 h 2 min 5 s el...
# 618  ENSP00000512455  1 min 19 s elapsed for process 0 h 1 min 19 s ...
# 619  ENSP00000512643  Minimizing g_r for node r=92 Minimizing g_r fo...
# 620  ENSP00000512834  1 min 53 s elapsed for process 0 h 1 min 53 s ...
#
#            Bin
# 0    1090_1099
# 1    1090_1099
# 2    1090_1099
# 3    1090_1099
# 4    1090_1099
# ..         ...
# 616      90_99
# 617      90_99
# 618      90_99
# 619      90_99
# 620      90_99
#
# [621 rows x 3 columns]

# %%
print(df_gplmdca["Filename"].isna().sum())
df_gplmdca = df_gplmdca.dropna()
df_gplmdca
# Out:
# 8
#             Filename                                     Execution_time  \
# 1    ENSP00000255194  58 min 52 s elapsed for process 10 h 58 min 52...
# 2    ENSP00000261778  1 min 18 s elapsed for process 17 h 1 min 18 s...
# 3    ENSP00000263409  29 min 49 s elapsed for process 14 h 29 min 49...
# 4    ENSP00000264160  18 min 10 s elapsed for process 9 h 18 min 10 ...
# 5    ENSP00000264868  11 min 5 s elapsed for process 5 h 11 min 5 s ...
# ..               ...                                                ...
# 616  ENSP00000504562  3 min 31 s elapsed for process 0 h 3 min 31 s ...
# 617  ENSP00000505395  2 min 5 s elapsed for process 0 h 2 min 5 s el...
# 618  ENSP00000512455  1 min 19 s elapsed for process 0 h 1 min 19 s ...
# 619  ENSP00000512643  Minimizing g_r for node r=92 Minimizing g_r fo...
# 620  ENSP00000512834  1 min 53 s elapsed for process 0 h 1 min 53 s ...
#
#            Bin
# 1    1090_1099
# 2    1090_1099
# 3    1090_1099
# 4    1090_1099
# 5    1090_1099
# ..         ...
# 616      90_99
# 617      90_99
# 618      90_99
# 619      90_99
# 620      90_99
#
# [613 rows x 3 columns]

# %%
df_gplmdca["h"] = df_gplmdca["Execution_time"].str.split('process').str[1].str.split('h').str[0]
df_gplmdca["m"] = df_gplmdca["Execution_time"].str.split('process').str[1].str.split('h').str[1].str.split('min').str[0]
df_gplmdca["s"] = df_gplmdca["Execution_time"].str.split('process').str[1].str.split('h').str[1].str.split('min').str[1].str.split('s').str[0]
df_gplmdca
# Out:
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\368034067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gplmdca["h"] = df_gplmdca["Execution_time"].str.split('process').str[1].str.split('h').str[0]
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\368034067.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gplmdca["m"] = df_gplmdca["Execution_time"].str.split('process').str[1].str.split('h').str[1].str.split('min').str[0]
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\368034067.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gplmdca["s"] = df_gplmdca["Execution_time"].str.split('process').str[1].str.split('h').str[1].str.split('min').str[1].str.split('s').str[0]
#             Filename                                     Execution_time  \
# 1    ENSP00000255194  58 min 52 s elapsed for process 10 h 58 min 52...
# 2    ENSP00000261778  1 min 18 s elapsed for process 17 h 1 min 18 s...
# 3    ENSP00000263409  29 min 49 s elapsed for process 14 h 29 min 49...
# 4    ENSP00000264160  18 min 10 s elapsed for process 9 h 18 min 10 ...
# 5    ENSP00000264868  11 min 5 s elapsed for process 5 h 11 min 5 s ...
# ..               ...                                                ...
# 616  ENSP00000504562  3 min 31 s elapsed for process 0 h 3 min 31 s ...
# 617  ENSP00000505395  2 min 5 s elapsed for process 0 h 2 min 5 s el...
# 618  ENSP00000512455  1 min 19 s elapsed for process 0 h 1 min 19 s ...
# 619  ENSP00000512643  Minimizing g_r for node r=92 Minimizing g_r fo...
# 620  ENSP00000512834  1 min 53 s elapsed for process 0 h 1 min 53 s ...
#
#            Bin     h     m     s
# 1    1090_1099   10    58    52
# 2    1090_1099   17     1    18
# 3    1090_1099   14    29    49
# 4    1090_1099    9    18    10
# 5    1090_1099    5    11     5
# ..         ...   ...   ...   ...
# 616      90_99    0     3    31
# 617      90_99    0     2     5
# 618      90_99    0     1    19
# 619      90_99   NaN   NaN   NaN
# 620      90_99    0     1    53
#
# [613 rows x 6 columns]

# %%
df_gplmdca.dtypes
# Out:
# Filename          object
# Execution_time    object
# Bin               object
# h                 object
# m                 object
# s                 object
# dtype: object

# %%
df_gplmdca = df_gplmdca.dropna()

# %%
df_gplmdca["h"] = df_gplmdca["h"].astype(int)
df_gplmdca["m"] = df_gplmdca["m"].astype(int)
df_gplmdca["s"] = df_gplmdca["s"].astype(int)
print(df_gplmdca.dtypes)
print(df_gplmdca)
# Out:
# Filename          object
# Execution_time    object
# Bin               object
# h                  int32
# m                  int32
# s                  int32
# dtype: object
#             Filename                                     Execution_time  \
# 1    ENSP00000255194  58 min 52 s elapsed for process 10 h 58 min 52...
# 2    ENSP00000261778  1 min 18 s elapsed for process 17 h 1 min 18 s...
# 3    ENSP00000263409  29 min 49 s elapsed for process 14 h 29 min 49...
# 4    ENSP00000264160  18 min 10 s elapsed for process 9 h 18 min 10 ...
# 5    ENSP00000264868  11 min 5 s elapsed for process 5 h 11 min 5 s ...
# ..               ...                                                ...
# 615  ENSP00000502347  2 min 43 s elapsed for process 0 h 2 min 43 s ...
# 616  ENSP00000504562  3 min 31 s elapsed for process 0 h 3 min 31 s ...
# 617  ENSP00000505395  2 min 5 s elapsed for process 0 h 2 min 5 s el...
# 618  ENSP00000512455  1 min 19 s elapsed for process 0 h 1 min 19 s ...
# 620  ENSP00000512834  1 min 53 s elapsed for process 0 h 1 min 53 s ...
#
#            Bin   h   m   s
# 1    1090_1099  10  58  52
# 2    1090_1099  17   1  18
# 3    1090_1099  14  29  49
# 4    1090_1099   9  18  10
# 5    1090_1099   5  11   5
# ..         ...  ..  ..  ..
# 615      90_99   0   2  43
# 616      90_99   0   3  31
# 617      90_99   0   2   5
# 618      90_99   0   1  19
# 620      90_99   0   1  53
#
# [565 rows x 6 columns]
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\1092703442.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gplmdca["h"] = df_gplmdca["h"].astype(int)
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\1092703442.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gplmdca["m"] = df_gplmdca["m"].astype(int)
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\1092703442.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gplmdca["s"] = df_gplmdca["s"].astype(int)

# %%
df_gplmdca["Total_s"] = df_gplmdca["h"] * 3600 + df_gplmdca["m"] * 60 + df_gplmdca["s"]
df_gplmdca
# Out:
# C:\Users\Yumika\AppData\Local\Temp\ipykernel_1492\314820177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gplmdca["Total_s"] = df_gplmdca["h"] * 3600 + df_gplmdca["m"] * 60 + df_gplmdca["s"]
#             Filename                                     Execution_time  \
# 1    ENSP00000255194  58 min 52 s elapsed for process 10 h 58 min 52...
# 2    ENSP00000261778  1 min 18 s elapsed for process 17 h 1 min 18 s...
# 3    ENSP00000263409  29 min 49 s elapsed for process 14 h 29 min 49...
# 4    ENSP00000264160  18 min 10 s elapsed for process 9 h 18 min 10 ...
# 5    ENSP00000264868  11 min 5 s elapsed for process 5 h 11 min 5 s ...
# ..               ...                                                ...
# 615  ENSP00000502347  2 min 43 s elapsed for process 0 h 2 min 43 s ...
# 616  ENSP00000504562  3 min 31 s elapsed for process 0 h 3 min 31 s ...
# 617  ENSP00000505395  2 min 5 s elapsed for process 0 h 2 min 5 s el...
# 618  ENSP00000512455  1 min 19 s elapsed for process 0 h 1 min 19 s ...
# 620  ENSP00000512834  1 min 53 s elapsed for process 0 h 1 min 53 s ...
#
#            Bin   h   m   s  Total_s
# 1    1090_1099  10  58  52    39532
# 2    1090_1099  17   1  18    61278
# 3    1090_1099  14  29  49    52189
# 4    1090_1099   9  18  10    33490
# 5    1090_1099   5  11   5    18665
# ..         ...  ..  ..  ..      ...
# 615      90_99   0   2  43      163
# 616      90_99   0   3  31      211
# 617      90_99   0   2   5      125
# 618      90_99   0   1  19       79
# 620      90_99   0   1  53      113
#
# [565 rows x 7 columns]

# %% [markdown]
# ## Merging each of the 2 dfs

# %% [markdown]
# ## pydca

# %%
# Merge pydca dfs
df_master_pydca = df_pydca.merge(df_base_pydca, how='inner', on='Filename')
df_master_pydca
# Out:
#             Filename                                     Execution_time  \
# 0    ENSP00000202556  0 h 0 min 25 s elapsed for process Trimmed_ENS...
# 1    ENSP00000205214  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# 2    ENSP00000255194  0 h 40 min 21 s elapsed for process Trimmed_EN...
# 3    ENSP00000261778  1 h 53 min 55 s elapsed for process Trimmed_EN...
# 4    ENSP00000261892  0 h 0 min 2 s elapsed for process Trimmed_ENSP...
# ..               ...                                                ...
# 795  ENSP00000505395  0 h 0 min 15 s elapsed for process Trimmed_ENS...
# 796  ENSP00000512455  0 h 0 min 4 s elapsed for process Trimmed_ENSP...
# 797  ENSP00000512643  0 h 0 min 10 s elapsed for process Trimmed_ENS...
# 798  ENSP00000512834  0 h 0 min 26 s elapsed for process Trimmed_ENS...
# 799  ENSP00000512907  0 h 0 min 5 s elapsed for process Trimmed_ENSP...
#
#          Bin_x  h   m   s  Total_s  MSA_size  Sequence_length      Bin_y
# 0    1090_1099  0   0  25       25      3056               89  1090_1099
# 1    1090_1099  0   0   2        2      6642                0  1090_1099
# 2    1090_1099  0  40  21     2421      2920              400  1090_1099
# 3    1090_1099  1  53  55     6835      1099              651  1090_1099
# 4    1090_1099  0   0   2        2      3194                0  1090_1099
# ..         ... ..  ..  ..      ...       ...              ...        ...
# 795      90_99  0   0  15       15      1013               52      90_99
# 796      90_99  0   0   4        4       534               31      90_99
# 797      90_99  0   0  10       10       488               56      90_99
# 798      90_99  0   0  26       26      1033               70      90_99
# 799      90_99  0   0   5        5       102               66      90_99
#
# [800 rows x 10 columns]

# %%
df_master_pydca = df_master_pydca[df_master_pydca["Sequence_length"] != 0]

# %% [markdown]
# ### Re-binning based on seuqnece length

# %%
# Re-grouping based on sequence length
df_master_pydca.loc[df_master_pydca['Sequence_length'] <= 99, 'seqlen_bin'] = '_99'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(100,199), 'seqlen_bin'] = '100_199'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(200,299), 'seqlen_bin'] = '200_299'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(300,499), 'seqlen_bin'] = '300_499'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(500,699), 'seqlen_bin'] = '500_699'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(700,899), 'seqlen_bin'] = '700_899'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(900,1099), 'seqlen_bin'] = '900_1099'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(1100,1299), 'seqlen_bin'] = '1100_1299'
df_master_pydca.loc[df_master_pydca['Sequence_length'].between(1300,1399), 'seqlen_bin'] = '1300_1399'
# Out:
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# C:\Users\Yumika\anaconda3-2\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df_master_pydca
# Out:
#             Filename                                     Execution_time  \
# 0    ENSP00000202556  0 h 0 min 25 s elapsed for process Trimmed_ENS...
# 2    ENSP00000255194  0 h 40 min 21 s elapsed for process Trimmed_EN...
# 3    ENSP00000261778  1 h 53 min 55 s elapsed for process Trimmed_EN...
# 5    ENSP00000263409  0 h 3 min 48 s elapsed for process Trimmed_ENS...
# 6    ENSP00000264160  0 h 2 min 52 s elapsed for process Trimmed_ENS...
# ..               ...                                                ...
# 795  ENSP00000505395  0 h 0 min 15 s elapsed for process Trimmed_ENS...
# 796  ENSP00000512455  0 h 0 min 4 s elapsed for process Trimmed_ENSP...
# 797  ENSP00000512643  0 h 0 min 10 s elapsed for process Trimmed_ENS...
# 798  ENSP00000512834  0 h 0 min 26 s elapsed for process Trimmed_ENS...
# 799  ENSP00000512907  0 h 0 min 5 s elapsed for process Trimmed_ENSP...
#
#          Bin_x  h   m   s  Total_s  MSA_size  Sequence_length      Bin_y  \
# 0    1090_1099  0   0  25       25      3056               89  1090_1099
# 2    1090_1099  0  40  21     2421      2920              400  1090_1099
# 3    1090_1099  1  53  55     6835      1099              651  1090_1099
# 5    1090_1099  0   3  48      228      5861              105  1090_1099
# 6    1090_1099  0   2  52      172      1164              134  1090_1099
# ..         ... ..  ..  ..      ...       ...              ...        ...
# 795      90_99  0   0  15       15      1013               52      90_99
# 796      90_99  0   0   4        4       534               31      90_99
# 797      90_99  0   0  10       10       488               56      90_99
# 798      90_99  0   0  26       26      1033               70      90_99
# 799      90_99  0   0   5        5       102               66      90_99
#
#     seqlen_bin
# 0          _99
# 2      300_499
# 3      500_699
# 5      100_199
# 6      100_199
# ..         ...
# 795        _99
# 796        _99
# 797        _99
# 798        _99
# 799        _99
#
# [607 rows x 11 columns]

# %%
df_master_pydca.describe()
# Out:
#                 h           m           s       Total_s     MSA_size  \
# count  607.000000  607.000000  607.000000    607.000000   607.000000
# mean     0.046129    6.472817   26.922570    581.354201  1839.749588
# std      0.252736   11.155169   17.606599   1293.575003  1298.906101
# min      0.000000    0.000000    0.000000      1.000000     1.000000
# 25%      0.000000    0.000000   12.000000     33.000000   758.500000
# 50%      0.000000    2.000000   25.000000    143.000000  1610.000000
# 75%      0.000000    7.000000   41.000000    466.000000  2637.500000
# max      3.000000   56.000000   59.000000  11305.000000  5861.000000
#
#        Sequence_length
# count       607.000000
# mean        147.563427
# std         118.079442
# min           2.000000
# 25%          73.500000
# 50%         118.000000
# 75%         178.500000
# max        1173.000000

# %%
binsize = 100
list_bins = [i for i in range (0, 1200, binsize)]
plt.hist(df_master_pydca["Sequence_length"], bins=list_bins)
plt.suptitle("Sequence length Distribution: n = " + str(df_master_pydca["Sequence_length"].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence length")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## Obtaining the results

# %%
## Obtaining the results
df_abin = df_master_pydca[df_master_pydca["seqlen_bin"] == "1100_1299"]
df_abin
bins = [-1, 250, 500, 750, 1000, 1250, np.inf]
labels=["-250", "250-500", "500-750", "750-1000", "1000-1250", "1250-"]
df_abin_grouped = df_abin.groupby(pd.cut(df_abin["MSA_size"], bins=bins, labels=labels)).mean()
#df_abin_grouped = df_abin.groupby(pd.cut(df_abin["MSA_size"], bins=bins, labels=labels)).size().reset_index(name='count')
df_abin_grouped
# Out:
#              h     m     s  Total_s  MSA_size  Sequence_length
# MSA_size
# -250       0.0  50.0  43.0   3043.0     123.0           1173.0
# 250-500    NaN   NaN   NaN      NaN       NaN              NaN
# 500-750    NaN   NaN   NaN      NaN       NaN              NaN
# 750-1000   NaN   NaN   NaN      NaN       NaN              NaN
# 1000-1250  NaN   NaN   NaN      NaN       NaN              NaN
# 1250-      NaN   NaN   NaN      NaN       NaN              NaN

# %% [markdown]
# ## gplmdca

# %%
# Merge gplmdca dfs
df_master_gplmdca = df_gplmdca.merge(df_base_gplmdca, how='inner', on='Filename')
df_master_gplmdca

# %%
# Keep only rows where Sequence_length is not 0
df_master_gplmdca = df_master_gplmdca[df_master_gplmdca["Sequence_length"] != 0]
df_master_gplmdca

# %%
df_master_gplmdca.describe()

# %%
binsize = 100
list_bins = [i for i in range (0, 1400, binsize)]
plt.hist(df_master_gplmdca["Sequence_length"], bins=list_bins)
plt.suptitle("Sequence length Distribution: n = " + str(df_master_gplmdca["Sequence_length"].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("Sequence length")
plt.ylabel("Frequency")

# %% [markdown]
# ## Obtaining the results

# %%
df_abin = df_master_gplmdca[df_master_gplmdca["Bin_x"] == "1290_1399"]
bins = [-1, 250, 500, 750, 1000, 1250, np.inf]
labels=["-250", "250-500", "500-750", "750-1000", "1000-1250", "1250-"]
df_abin_grouped = df_abin.groupby(pd.cut(df_abin["MSA_size"], bins=bins, labels=labels)).mean()
df_abin_grouped

# %% [markdown]
# ## Graphing MSA size distribution

# %%
binsize = 250
list_bins = [i for i in range (0, 2000, binsize)]
plt.hist(df_master_gplmdca["MSA_size"], bins=list_bins)
plt.suptitle("MSA size Distribution: n = " + str(df_master_gplmdca["MSA_size"].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("MSA Size")
plt.ylabel("Frequency")

# %% [markdown]
# ## Merge the two merged dataframes

# %%
df_master = df_master_gplmdca.merge(df_master_pydca, how="inner", on="Filename", suffixes=('_gplmdca', '_pydca'))
df_master

# %%
df_master["Sequence_length"].value_counts()

# %%
df_master[df_master["Sequence_length"] == 0].value_counts("Total_s_y")

# %%
df_master['Bin_match'] = np.where(df_master['Bin_x'] == df_master['Bin_y'], 
                                           'yes', 'no')
df_master["Bin_match"].value_counts()

# %%
df_succ = df_master[["Filename", "Total_s_gplmdca", "MSA_size_gplmdca", "Sequence_length_gplmdca", "Total_s_pydca", "MSA_size_pydca", "Sequence_length_pydca", "Bin_x_gplmdca", "h_gplmdca", "m_gplmdca", "s_gplmdca","Bin_x_pydca", "h_pydca", "m_pydca", "s_pydca"]]
df_succ

# %%
df_abin = df_succ[df_succ["Bin_x_pydca"] == "90_99"]
df_abin

# %%
df_abin.describe()

# %%
binsize = 250
list_bins = [i for i in range (0, 10000, binsize)]
plt.hist(df_abin["MSA_size"], bins=list_bins)
plt.suptitle("MSA size Distribution: n = " + str(df_abin["MSA_size"].shape[0]))
plt.title("bin size: " + str(binsize))
plt.xlabel("MSA Size")
plt.ylabel("Frequency")
