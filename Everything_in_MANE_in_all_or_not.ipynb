# %%
import pandas as pd

# %%
# read iso_all
f_iso_all = "iso_all_v1.1.csv"
df_iso_all = pd.read_csv(f_iso_all)
df_iso_all
# Out:
#                    CHESS ID     GENE           RefSeq ID         GENCODE ID  \
# 0                  CHS.15.1   OR4F29  rna-NM_001005221.2  ENST00000426406.4
# 1                  CHS.39.7   SAMD11  rna-NM_001385641.1  ENST00000616016.5
# 2                  CHS.40.3    NOC2L     rna-NM_015658.4  ENST00000327044.7
# 3                 CHS.41.11  PLEKHN1     rna-NM_032129.3  ENST00000379410.8
# 4                  CHS.42.6   KLHL17     rna-NM_198317.3  ENST00000338591.8
# ...                     ...      ...                 ...                ...
# 194775  hypothetical.2081.1        -  rna-NM_001005182.2  ENST00000642104.1
# 194776  hypothetical.2082.1        -  rna-NM_001348233.2  ENST00000540461.2
# 194777  hypothetical.2083.1        -  rna-NM_001005166.5  ENST00000610445.2
# 194778  hypothetical.2084.1        -  rna-NM_001005468.2  ENST00000641451.2
# 194779  hypothetical.2085.1        -  rna-NM_001369203.1  ENST00000494082.3
#
#         pLDDT introns in mouse
# ...

# %%
# read iso_MANE
f_iso_MANE = "iso_MANE_cim_fixed.csv" # could be "iso_MANE_cim_fixed_nohypo.csv" for our purpose
df_iso_MANE = pd.read_csv(f_iso_MANE)
df_iso_MANE
# Out:
#                    CHESS_ID        CHESS_ID_MANE     gene  aa_length_isoform  \
# 0               CHS.59119.2          CHS.59119.2    CLIC2                247
# 1               CHS.59109.2          CHS.59109.2    SMIM9                 99
# 2               CHS.59041.5          CHS.59041.5     PNCK                343
# 3       hypothetical.1792.2  hypothetical.1792.2   PNMA6E                647
# 4               CHS.58995.1          CHS.58995.1  MAGEA10                369
# ...                     ...                  ...      ...                ...
# 107508         CHS.59041.27          CHS.59041.5     PNCK                 86
# 107509          CHS.59109.1          CHS.59109.2    SMIM9                 99
# 107510  hypothetical.1794.1          CHS.59119.2    CLIC2                236
# 107511  hypothetical.1794.2          CHS.59119.2    CLIC2                232
# 107512          CHS.59119.5          CHS.59119.2    CLIC2                229
#
# ...

# %% [markdown]
# ### Creating two lists of CHESS_ID to search difference

# %%
unique_chess_Id_all = list(df_iso_all["CHESS ID"].unique())
print(len(unique_chess_Id_all))
# Out:
# 194780

# %%
unique_chess_Id_MANE = list(df_iso_MANE["CHESS_ID"].unique())
print(len(unique_chess_Id_MANE))
# Out:
# 107379

# %%
# Get difference between two lists
difference = list(set(unique_chess_Id_all) - set(unique_chess_Id_MANE))
print(len(difference))
print((194780-107379)==87401)
# Out:
# 87401
# True
